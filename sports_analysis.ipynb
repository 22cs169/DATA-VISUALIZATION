# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the provided data
data = pd.DataFrame({
    "coachID": [
        "patrile01c", "irvindi01c", "patrile01c", "irvindi01c", "patrile01c", "irvindi01c",
        "patrile01c", "irvindi01c", "patrile01c", "irvindi01c", "patrile01c", "gormato01c",
        "adamsja01c", "hartce01c", "patrile01c", "rossar01c", "rossar01c", "duttore01c",
        "thomppa01c", "bouchfr01c", "weilaco01c", "irvindi01c", "bouchfr01c", "thomppa01c",
        "adamsja01c", "rossar01c", "irvindi01c"
    ],
    "award": [
        "First Team All-Star", "Second Team All-Star", "First Team All-Star", "Second Team All-Star",
        "First Team All-Star", "Second Team All-Star", "First Team All-Star", "Second Team All-Star",
        "First Team All-Star", "Second Team All-Star", "First Team All-Star", "Second Team All-Star",
        "First Team All-Star", "Second Team All-Star", "First Team All-Star", "Second Team All-Star",
        "First Team All-Star", "Second Team All-Star", "First Team All-Star", "Second Team All-Star",
        "First Team All-Star", "Second Team All-Star", "First Team All-Star", "Second Team All-Star",
        "First Team All-Star", "Second Team All-Star", "First Team All-Star"
    ],
    "year": [
        1930, 1930, 1931, 1931, 1932, 1932, 1933, 1933, 1934, 1934, 1935, 1935, 1936, 1936, 1937, 1937,
        1938, 1938, 1939, 1939, 1940, 1940, 1941, 1941, 1942, 1942, 1943
    ],
    "lgID": [
        "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL",
        "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL", "NHL",
        "NHL", "NHL", "NHL"
    ],
})

# Visualize the data
# For example, create a stacked bar chart to compare awards by year
plt.figure(figsize=(10, 6))
award_counts = data.groupby(['year', 'award']).size().unstack().fillna(0)
award_counts.plot(kind='bar', stacked=True)
plt.title('Awards by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Award Type')
plt.show()

# Create a radar chart to visualize awards by coachID
plt.figure(figsize=(10, 6))
award_counts = data.groupby(['coachID', 'award']).size().unstack().fillna(0)
award_counts.plot(kind='bar', stacked=True)
plt.title('Awards by CoachID')
plt.xlabel('CoachID')
plt.ylabel('Count')
plt.legend(title='Award Type')
plt.show()
